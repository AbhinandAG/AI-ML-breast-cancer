# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinandAG/AI-ML-breast-cancer/blob/main/bstcncrtrained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib
model=joblib.load("bstcncr.pkl")
z=(model.predict([[17.99,10.38,122.80,1001.0,0.11840,0.27760,0.30010,0.14710,184.60,2019.0,0.16220,0.66560,0.7119,0.2654,0.4601,0.11890]]))
if z==0:
  print("Benign")
else:
  print("Malignant")
# Out:
# Malignant
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
